# %%
import pandas as pd
import os

# %%
files = os.listdir('../raw_data')

# %%
data = {f: pd.read_excel('../raw_data/'+f) for f in files }

# %%
parking = data['Hack4Cause_Parking Citations FY 2008.xls']
parking.columns
# Out:
# Index(['Date', 'Make', 'Color', 'Amount Due', 'Violation', 'Location', 'Meter',
#        'Officer Comment'],
#       dtype='object')

# %%
clean = parking.dropna(how='all')
clean
# Out:
#             Date  Make Color  Amount Due           Violation  \
# 0     2007-07-01  ACUR   SIL         0.0  RESTRICTED BY SIGN
# 2     2007-07-02  SAAB   BLK         0.0     METER VIOLATION
# 4     2007-07-02  SAAB   BLK         0.0             LEVEL 4
# 6     2007-07-02  VOLV   WHT         0.0     METER VIOLATION
# 8     2007-07-02  TOYT   WHT         0.0     METER VIOLATION
# 10    2007-07-02  LEXS   GRY        24.0     METER VIOLATION
# 12    2007-07-02  TOYT   GRY         0.0     METER VIOLATION
# 14    2007-07-02  DODG   BLU         0.0  WRONG SIDE PARKING
# 16    2007-07-02   GMC   BLK         0.0     METER VIOLATION
# 18    2007-07-02  HOND   GRY         0.0     METER VIOLATION
# 20    2007-07-02  CHEV   BLK         0.0     METER VIOLATION
# 22    2007-07-02  SUBA   BLU         0.0     METER VIOLATION
# 24    2007-07-02  HOND   MAR         0.0     METER VIOLATION
# 26    2007-07-02  ACUR   BLU         0.0     METER VIOLATION
# 28    2007-07-02  FORD   RED         0.0     METER VIOLATION
# 30    2007-07-02  MAZD   RED         0.0     METER VIOLATION
# 32    2007-07-02  HOND   BLK         0.0     METER VIOLATION
# 34    2007-07-02  HOND   BLK        24.0     METER VIOLATION
# 36    2007-07-02  TOYT   GRN        30.0  RESTRICTED BY SIGN
# 38    2007-07-02  SUBA   WHT         0.0     METER VIOLATION
# 40    2007-07-02  NISS   GRN         0.0     METER VIOLATION
# 42    2007-07-02  TOYT   BLU         0.0     METER VIOLATION
# 44    2007-07-02  CHEV   WHT         0.0     METER VIOLATION
# 46    2007-07-02  CHEV   GRY         0.0     METER VIOLATION
# 48    2007-07-02  VOLK   BLU         0.0     METER VIOLATION
# 50    2007-07-02  FORD   GRN         0.0     METER VIOLATION
# 52    2007-07-02  FORD   RED         0.0     METER VIOLATION
# 54    2007-07-02  TOYT   BEI         0.0     METER VIOLATION
# 56    2007-07-02  HOND   BLU         0.0     METER VIOLATION
# 58    2007-07-02  ISUZ   RED         0.0     METER VIOLATION
# ...          ...   ...   ...         ...                 ...
# 65458 2008-01-07  SUBA   RED         0.0     METER VIOLATION
# 65460 2008-01-07  TOYT   BLK         0.0     METER VIOLATION
# 65462 2008-01-07  FORD   GRY        24.0     METER VIOLATION
# 65464 2008-01-07  HOND   BLU         0.0  RESTRICTED BY SIGN
# 65466 2008-01-07  VOLK   GRY         0.0     TIME LIMIT ZONE
# 65468 2008-01-07  DODG   WHT         0.0     TIME LIMIT ZONE
# 65470 2008-01-07  VOLK   WHT         0.0     TIME LIMIT ZONE
# 65472 2008-01-07  TOYT   BLK         0.0     TIME LIMIT ZONE
# 65474 2008-01-07  SUBA   BLU         0.0     TIME LIMIT ZONE
# 65476 2008-01-07  SUBA   BLU         0.0     METER VIOLATION
# 65478 2008-01-07  CHEV   GRY         0.0     METER VIOLATION
# 65480 2008-01-07  TOYT   GRY         0.0     METER VIOLATION
# 65482 2008-01-07  FORD   WHT         0.0     TIME LIMIT ZONE
# 65484 2008-01-07  SUBA   BLU         0.0     METER VIOLATION
# 65486 2008-01-07  ISUZ   GRY         0.0     METER VIOLATION
# 65488 2008-01-07  TOYT   WHT         0.0     METER VIOLATION
# 65490 2008-01-07  FORD   GRY         0.0     METER VIOLATION
# 65492 2008-01-07  JEEP   GRY         0.0     TIME LIMIT ZONE
# 65494 2008-01-07  HOND   MAR         0.0     TIME LIMIT ZONE
# 65496 2008-01-07  AUDI   RED         0.0     TIME LIMIT ZONE
# 65498 2008-01-07  HOND   BLU         0.0     TIME LIMIT ZONE
# 65500 2008-01-07  TOYT   RED        24.0     TIME LIMIT ZONE
# 65502 2008-01-07  DODG   SIL         0.0         YELLOW ZONE
# 65504 2008-01-07  HOND   GRN         0.0     METER VIOLATION
# 65506 2008-01-07  HOND   GRN         0.0  RESTRICTED BY SIGN
# 65508 2008-01-07  SUZU   MAR         0.0     METER VIOLATION
# 65510 2008-01-07  COOP   GRN         0.0     TIME LIMIT ZONE
# 65512 2008-01-07  FORD   GRN         0.0     TIME LIMIT ZONE
# 65514 2008-01-07  SUBA   WHT         0.0     TIME LIMIT ZONE
# 65516 2008-01-07  SUBA   GRY         0.0     METER VIOLATION
#
#                           Location   Meter  \
# 0         LOT 07  - EUGENE AIRPORT     NaN
# 2       E/S KINCAID - 14TH TO 13TH  227-67
# 4       E/S KINCAID - 14TH TO 13TH     NaN
# 6      N/S 13TH - ALDER TO KINCAID  214-42
# 8         ALDER ST 13TH AVE 12TH A  214 52
# 10        KINCAID ST 12TH AVE 13TH  214 15
# 12        13TH AVE KINCAID ST ALDE   226 6
# 14        GARDEN AVE VILLARD ST MO     NaN
# 16        KINCAID ST 11TH AVE 12TH  209 21
# 18        13TH AVE COLUMBIA ST AGA   234 4
# 20        13TH AVE AGATE ST COLUMB  222 46
# 22        15TH AVE MOSS ST AGATE S   256 6
# 24        ALDER ST 12TH AVE 11TH A  209 51
# 26        ALDER ST 12TH AVE 11TH A  208 25
# 28        ALDER ST 13TH AVE 12TH A  214 53
# 30        CHARNELTON ST 8TH AVE 7T   31 51
# 32        OLIVE ST BROADWAY ST 10T   50 50
# 34        WILLAMETTE BROADWAY ST 8   41 18
# 36        PEARL ST BROADWAY ST 8TH     NaN
# 38        BROADWAY ST OAK ST PEARL   43 34
# 40        BROADWAY ST LINCOLN ST C   39 31
# 42        CHARNELTON ST 8TH AVE 7T   31 46
# 44                    LOT 31 ALLEY   39 98
# 46                          LOT 21   SP.81
# 48                          LOT 31   SP.49
# 50                     WEST PARK-8   42-66
# 52                   SOUTH PARK-1E   43-64
# 54        8TH AVE OLIVE ST WILLAME   41-12
# 56                   SOUTH PARK-1E   43-67
# 58          OAK ST 6TH AVE 7TH AVE   25-46
# ...                            ...     ...
# 65458     KINCAID ST 14TH AVE 13TH  226-20
# 65460     13TH AVE KINCAID ST ALDE  226-10
# 65462     AGATE ST 17TH AVE 15TH A  255-32
# 65464     15TH AVE ALDER ST KINCAI     NaN
# 65466      WALNUT ST 15TH AVE 17TH     NaN
# 65468     COLUMBIA ST 17TH AVE 19T     NaN
# 65470     17TH AVE MOSS ST COLUMBI     NaN
# 65472     17TH AVE VILLARD ST MOSS     NaN
# 65474     VILLARD ST 15TH AVE 17TH     NaN
# 65476     BROADWAY ST PEARL ST OAK    52 2
# 65478                       LOT 15      17
# 65480     BROADWAY ST CHARNELTON S   40 37
# 65482             ALLEY OVERPARK S     NaN
# 65484                       LOT 21      51
# 65486     LINCOLN ST 10TH AVE 11TH   56 17
# 65488     10TH AVE OLIVE ST CHARNE   58 13
# 65490     PEARL ST 14TH AVE 13TH A   91 18
# 65492     KINCAID ST 18TH AVE 19TH     NaN
# 65494     19TH AVE EMERALD ST AGAT     NaN
# 65496     ONYX ST 18TH AVE 19TH AV     NaN
# 65498     ONYX ST 18TH AVE 19TH AV     NaN
# 65500     ONYX ST 21ST AVE 20TH AV     NaN
# 65502     14TH AVE KINCAID ST ALDE     NaN
# 65504     KINCAID ST 15TH AVE 14TH  239-16
# 65506     15TH AVE ALDER ST KINCAI     NaN
# 65508      KINCAID ST END 15TH AVE  250-20
# 65510      HARRIS ST 19TH AVE 20TH     NaN
# 65512     20TH AVE UNIVERSITY ST O     NaN
# 65514     20TH AVE ONYX ST UNIVERS     NaN
# 65516     18TH AVE HARRIS ST POTTE  272-30
#
#                             Officer Comment
# 0              TERMINAL LOADING / UNLOADING
# 2                          NO TIME ON METER
# 4                                       NaN
# 6                          NO TIME ON METER
# 8                          NO TIME ON METER
# 10                         NO TIME ON METER
# 12                         NO TIME ON METER
# 14      MUST PARK WITH FLOW OF TRAFFIC2 WAY
# 16                         NO TIME ON METER
# 18                         NO TIME ON METER
# 20                         NO TIME ON METER
# 22                 NO TIME ON METERNO DECAL
# 24                         NO TIME ON METER
# 26                         NO TIME ON METER
# 28                         NO TIME ON METER
# 30                         NO TIME ON METER
# 32                         NO TIME ON METER
# 34                         NO TIME ON METER
# 36         COMMERCIAL MARKED VEHICLE ONLYNV
# 38                         NO TIME ON METER
# 40                         NO TIME ON METER
# 42                         NO TIME ON METER
# 44                         NO TIME ON METER
# 46                         NO TIME ON METER
# 48                         NO TIME ON METER
# 50                         NO TIME ON METER
# 52                         NO TIME ON METER
# 54                         NO TIME ON METER
# 56                         NO TIME ON METER
# 58                         NO TIME ON METER
# ...                                     ...
# 65458                      NO TIME ON METER
# 65460                      NO TIME ON METER
# 65462                      NO TIME ON METER
# 65464  COMMERCIAL MARKED VEHICLE ONLYNO COM
# 65466  NO PERMIT VISIBLECHALK MARK STILL VI
# 65468  NO PERMIT VISIBLECHALK MARK STILL VI
# 65470  NO PERMIT VISIBLECHALK MARK STILL VI
# 65472  NO PERMIT VISIBLECHALK MARK STILL VI
# 65474  NO PERMIT VISIBLECHALK MARK STILL VI
# 65476                      NO TIME ON METER
# 65478            NO TIME ON METER9.05  O.K.
# 65480                      NO TIME ON METER
# 65482  CHALK MARK STILL VISIBLE30 MINUTES O
# 65484                      NO TIME ON METER
# 65486                      NO TIME ON METER
# 65488                      NO TIME ON METER
# 65490                      NO TIME ON METER
# 65492  CHALK MARK STILL VISIBLENO PERMIT VI
# 65494              CHALK MARK STILL VISIBLE
# 65496  CHALK MARK STILL VISIBLENO PERMIT VI
# 65498  CHALK MARK STILL VISIBLENO PERMIT VI
# 65500  CHALK MARK STILL VISIBLENO PERMIT VI
# 65502                   NOT A PARKING SPACE
# 65504                      NO TIME ON METER
# 65506  COMMERCIAL MARKED VEHICLE ONLYNO COM
# 65508                      NO TIME ON METER
# 65510  CHALK MARK STILL VISIBLENO PERMIT VI
# 65512  CHALK MARK STILL VISIBLENO PERMIT VI
# 65514  CHALK MARK STILL VISIBLENO PERMIT VI
# 65516                      NO TIME ON METER
#
# [32759 rows x 8 columns]
